# %%
from requests_html import HTMLSession
session = HTMLSession()

# %%
URL = "https://www.lagou.com/jobs/list_%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98?px=default&city=%E5%85%A8%E5%9B%BD#filterBox"

# %%
r = session.get(URL)

# %%
r

# %%
x = r.html.find("#s_position_list")[0]

# %%
x
# Out:
# <Element 'div' class=('s_position_list',) id='s_position_list'>

# %%
x0 = x.find('.item_con_list')[0]
x0
# Out:
# <Element 'ul' class=('item_con_list',) style='display: block;'>

# %%
x1 = x0.find('ul')[0]

# %%
x2 = x1.find('li')

# %%
y.text
# Out:
# '数据挖掘工程师\n[北京·呼家楼] 1天前发布\n18k-30k 经验3-5年 / 硕士\n商询科技该企业已上传营业执照并通过资质验证审核\n企业服务,数据服务 / A轮\n金融 hadoop 算法 机器学习 大数据\n“五险一金”'

# %%
for y in x2:
    for k in y.absolute_links:
        if 'job' in k:
            print(k)
# Out:
# https://www.lagou.com/jobs/4056728.html
# https://www.lagou.com/jobs/4168652.html
# https://www.lagou.com/jobs/4179579.html
# https://www.lagou.com/jobs/4180315.html
# https://www.lagou.com/jobs/3884110.html
# https://www.lagou.com/jobs/3948326.html
# https://www.lagou.com/jobs/4126354.html
# https://www.lagou.com/jobs/4184367.html
# https://www.lagou.com/jobs/4181138.html
# https://www.lagou.com/jobs/3700750.html
# https://www.lagou.com/jobs/2795702.html
# https://www.lagou.com/jobs/3845207.html
# https://www.lagou.com/jobs/4161192.html
# https://www.lagou.com/jobs/4187447.html
# https://www.lagou.com/jobs/3827305.html

# %%
for i in x0:
    print(i.absolute_links)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-84027978086f> in <module>()
# ----> 1 for i in x0:
#       2     print(i.absolute_links)
#
# TypeError: 'Element' object is not iterable

# %%
r.html.render()

# %%
Rj = '''
{
  "success": true,
  "requestId": null,
  "resubmitToken": null,
  "msg": null,
  "content": {
    "pageNo": 4,
    "pageSize": 15,
    "hrInfoMap": {
      "1302830": {
        "userId": 674265,
        "positionName": "HR",
        "phone": null,
        "receiveEmail": null,
        "realName": "辛琳",
        "portrait": null,
        "userLevel": "G1",
        "canTalk": true
      },
      "2603441": {
        "userId": 1314138,
        "positionName": "招聘",
        "phone": null,
        "receiveEmail": null,
        "realName": "李女士",
        "portrait": null,
        "userLevel": "G1",
        "canTalk": true
      },
      "3284227": {
        "userId": 8074431,
        "positionName": "",
        "phone": null,
        "receiveEmail": null,
        "realName": "vicky",
        "portrait": null,
        "userLevel": "G1",
        "canTalk": true
      },
      "3440369": {
        "userId": 5314132,
        "positionName": "HR",
        "phone": null,
        "receiveEmail": null,
        "realName": "京东HR",
        "portrait": null,
        "userLevel": "G1",
        "canTalk": true
      },
      "3444397": {
        "userId": 2117266,
        "positionName": "HR",
        "phone": null,
        "receiveEmail": null,
        "realName": "raoying",
        "portrait": "i/image/M00/4B/CC/CgpEMllnaAuARvblAAAgJXYyQFE826.jpg",
        "userLevel": "G1",
        "canTalk": true
      },
      "3865597": {
        "userId": 9378160,
        "positionName": "HR",
        "phone": null,
        "receiveEmail": null,
        "realName": "Round_Gu",
        "portrait": "i/image2/M00/22/67/CgoB5loU7ASAF9QYAAAT-IlnVKU019.jpg",
        "userLevel": "G1",
        "canTalk": true
      },
      "3954556": {
        "userId": 398573,
        "positionName": "HRD",
        "phone": null,
        "receiveEmail": null,
        "realName": "杜强",
        "portrait": "i/image2/M00/2B/DB/CgoB5louAzKAZ9iRAAHF1vsihGE953.jpg",
        "userLevel": "G1",
        "canTalk": true
      },
      "4002047": {
        "userId": 4602257,
        "positionName": "招聘经理",
        "phone": null,
        "receiveEmail": null,
        "realName": "荔枝",
        "portrait": "i/image3/M00/07/64/CgpOIFpgYreAVoxoAAAnKw6Ka6U608.png",
        "userLevel": "G1",
        "canTalk": true
      },
      "4043884": {
        "userId": 817467,
        "positionName": null,
        "phone": null,
        "receiveEmail": null,
        "realName": "jianmindong",
        "portrait": null,
        "userLevel": "G1",
        "canTalk": true
      },
      "4112498": {
        "userId": 308573,
        "positionName": "hr",
        "phone": null,
        "receiveEmail": null,
        "realName": "job",
        "portrait": null,
        "userLevel": "G1",
        "canTalk": true
      },
      "4142085": {
        "userId": 9328501,
        "positionName": null,
        "phone": null,
        "receiveEmail": null,
        "realName": "king.niu",
        "portrait": "i/image3/M00/0B/4E/CgpOIFpltnGANDYGAAE1UmDwaoY226.jpg",
        "userLevel": "G1",
        "canTalk": true
      },
      "4155959": {
        "userId": 3032901,
        "positionName": "",
        "phone": null,
        "receiveEmail": null,
        "realName": "拼多多",
        "portrait": "i/image3/M00/12/2E/Cgq2xlpuujqABk5zAACNNLlNdT0373.png",
        "userLevel": "G1",
        "canTalk": true
      },
      "4169884": {
        "userId": 7131879,
        "positionName": "",
        "phone": null,
        "receiveEmail": null,
        "realName": "huiying.bai",
        "portrait": null,
        "userLevel": "G1",
        "canTalk": true
      },
      "4179164": {
        "userId": 9582063,
        "positionName": "HR",
        "phone": null,
        "receiveEmail": null,
        "realName": "祝婷婷",
        "portrait": "i/image3/M00/07/03/Cgq2xlpgPkSAMGd8AAEKuUqnF4U102.jpg",
        "userLevel": "G1",
        "canTalk": true
      },
      "4188488": {
        "userId": 5891175,
        "positionName": "创始人",
        "phone": null,
        "receiveEmail": null,
        "realName": "Jack Liu",
        "portrait": "i/image3/M00/1C/2B/Cgq2xlqCnKqAKszmAABEKukya3k181.jpg",
        "userLevel": "G1",
        "canTalk": true
      }
    },
    "positionResult": {
      "resultSize": 15,
      "hotLabels": null,
      "hiTags": null,
      "locationInfo": {
        "city": null,
        "district": null,
        "queryByGisCode": false,
        "locationCode": null,
        "isAllhotBusinessZone": false,
        "businessZone": null
      },
      "totalCount": 1114,
      "queryAnalysisInfo": {
        "positionName": "数据挖掘",
        "companyName": null,
        "industryName": null,
        "usefulCompany": false
      },
      "strategyProperty": {
        "name": "dm-csearch-useUserAllInterest",
        "id": 0
      },
      "result": [
        {
          "companyId": 436,
          "hitags": null,
          "resumeProcessRate": 43,
          "resumeProcessDay": 1,
          "companyFullName": "奇虎360科技有限公司",
          "imState": "today",
          "lastLogin": 1519903540000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘/机器学习工程师",
          "workYear": "3-5年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 1302830,
          "companyShortName": "360",
          "createTime": "2018-02-26 18:59:38",
          "score": 0,
          "city": "北京",
          "salary": "25k-35k",
          "positionAdvantage": "股票 保险 免费三餐",
          "approve": 1,
          "financeStage": "上市公司",
          "industryField": "移动互联网,游戏",
          "companySize": "2000人以上",
          "companyLabelList": [],
          "publisherId": 674265,
          "district": "朝阳区",
          "companyLogo": "image1/M00/26/1E/Cgo8PFVUDROAf7zrAABr5cEcbGQ572.jpg",
          "positionLables": [
            "广告营销"
          ],
          "industryLables": [
            "广告营销"
          ],
          "businessZones": [
            "酒仙桥",
            "大山子",
            "将台路"
          ],
          "longitude": "116.49012",
          "latitude": "39.98343006",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "技术",
          "secondType": "后端开发",
          "isSchoolJob": 0,
          "subwayline": "14号线东段",
          "stationname": "望京南",
          "linestaion": "14号线东段_望京南;14号线东段_将台",
          "formatCreateTime": "3天前发布"
        },
        {
          "companyId": 156250,
          "hitags": null,
          "resumeProcessRate": 84,
          "resumeProcessDay": 1,
          "companyFullName": "华人谷（江苏）网络技术有限公司",
          "imState": "today",
          "lastLogin": 1519905778000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师P26",
          "workYear": "1-3年",
          "education": "大专",
          "jobNature": "全职",
          "positionId": 4188488,
          "companyShortName": "华人谷",
          "createTime": "2018-03-01 19:24:21",
          "score": 0,
          "city": "苏州",
          "salary": "10k-20k",
          "positionAdvantage": "住房补贴,每月福利,培训,节日补贴",
          "approve": 0,
          "financeStage": "未融资",
          "industryField": "移动互联网",
          "companySize": "15-50人",
          "companyLabelList": [
            "交通补助",
            "午餐补助",
            "技能培训",
            "家属奖"
          ],
          "publisherId": 5891175,
          "district": "姑苏区",
          "companyLogo": "i/image3/M00/1E/1B/CgpOIFqPkBeAUggrAAA7BzAm7hQ549.jpg",
          "positionLables": [],
          "industryLables": [],
          "businessZones": null,
          "longitude": "120.617296",
          "latitude": "31.336392",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "4号线",
          "stationname": "苏州火车站",
          "linestaion": "2号线_平泷路东;2号线_平河路;2号线_苏州火车站;4号线_苏锦;4号线_苏州火车站",
          "formatCreateTime": "19:24发布"
        },
        {
          "companyId": 139755,
          "hitags": null,
          "resumeProcessRate": 1,
          "resumeProcessDay": 1,
          "companyFullName": "北京京东世纪贸易有限公司",
          "imState": "today",
          "lastLogin": 1519898916000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "3-5年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 3440369,
          "companyShortName": "京东商城",
          "createTime": "2018-03-01 14:38:52",
          "score": 0,
          "city": "北京",
          "salary": "15k-30k",
          "positionAdvantage": "餐补,弹性工作,大平台,免费班车",
          "approve": 1,
          "financeStage": "上市公司",
          "industryField": "电子商务",
          "companySize": "2000人以上",
          "companyLabelList": [
            "免费班车",
            "子女教育计划",
            "安居计划",
            "救助基金"
          ],
          "publisherId": 5314132,
          "district": "大兴区",
          "companyLogo": "i/image2/M00/01/B5/CgoB5lm_Z2eAO7g_AAAsw5Ww4Ig707.jpg",
          "positionLables": [
            "物流",
            "大数据",
            "算法"
          ],
          "industryLables": [
            "物流",
            "大数据",
            "算法"
          ],
          "businessZones": [
            "亦庄",
            "亦庄"
          ],
          "longitude": "116.50601",
          "latitude": "39.793232",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "亦庄线",
          "stationname": "荣京东街",
          "linestaion": "亦庄线_万源街;亦庄线_荣京东街",
          "formatCreateTime": "14:38发布"
        },
        {
          "companyId": 3038,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 1,
          "companyFullName": "北京国双科技有限公司",
          "imState": "today",
          "lastLogin": 1519892241000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "3-5年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 2603441,
          "companyShortName": "Gridsum 国双",
          "createTime": "2018-03-01 11:12:48",
          "score": 0,
          "city": "北京",
          "salary": "20k-40k",
          "positionAdvantage": "六险一金、弹性工作、奖金丰厚、技术牛人多",
          "approve": 1,
          "financeStage": "上市公司",
          "industryField": "数据服务,企业服务",
          "companySize": "500-2000人",
          "companyLabelList": [
            "年度旅游",
            "节日礼物",
            "年底双薪",
            "带薪年假"
          ],
          "publisherId": 1314138,
          "district": "海淀区",
          "companyLogo": "image1/M00/00/08/Cgo8PFTUWA-AdaTRAAA79zuDOBc464.jpg",
          "positionLables": [
            "机器学习",
            "大数据"
          ],
          "industryLables": [],
          "businessZones": [
            "中关村",
            "知春路",
            "双榆树"
          ],
          "longitude": "116.33175",
          "latitude": "39.97599007",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "10号线",
          "stationname": "知春路",
          "linestaion": "4号线大兴线_人民大学;4号线大兴线_海淀黄庄;10号线_海淀黄庄;10号线_知春里;10号线_知春路;13号线_知春路",
          "formatCreateTime": "11:12发布"
        },
        {
          "companyId": 29151,
          "hitags": null,
          "resumeProcessRate": 86,
          "resumeProcessDay": 2,
          "companyFullName": "北京陌上花科技有限公司",
          "imState": "today",
          "lastLogin": 1519895513000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "3-5年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 3954556,
          "companyShortName": "Yi+",
          "createTime": "2018-03-01 11:21:38",
          "score": 0,
          "city": "北京",
          "salary": "25k-50k",
          "positionAdvantage": "股票期权,技术大牛,晋升空间,弹性工作",
          "approve": 1,
          "financeStage": "B轮",
          "industryField": "移动互联网",
          "companySize": "15-50人",
          "companyLabelList": [
            "股票期权",
            "岗位晋升",
            "弹性工作",
            "绩效奖金"
          ],
          "publisherId": 398573,
          "district": "海淀区",
          "companyLogo": "i/image/M00/89/A1/CgqKkVhzBUiAVAPnAAA4WxlD0ls304.png",
          "positionLables": [
            "广告营销",
            "文化娱乐",
            "搜索",
            "数据分析",
            "算法"
          ],
          "industryLables": [
            "广告营销",
            "文化娱乐",
            "搜索",
            "数据分析",
            "算法"
          ],
          "businessZones": [
            "中关村",
            "苏州街",
            "人民大学"
          ],
          "longitude": "116.313649",
          "latitude": "39.978272",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "10号线",
          "stationname": "海淀黄庄",
          "linestaion": "4号线大兴线_人民大学;4号线大兴线_海淀黄庄;4号线大兴线_中关村;10号线_苏州街;10号线_海淀黄庄;10号线_知春里",
          "formatCreateTime": "11:21发布"
        },
        {
          "companyId": 25592,
          "hitags": null,
          "resumeProcessRate": 8,
          "resumeProcessDay": 1,
          "companyFullName": "新浪网技术（中国）有限公司",
          "imState": "disabled",
          "lastLogin": 1519875477000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "1-3年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 3284227,
          "companyShortName": "新浪网",
          "createTime": "2018-03-01 11:03:56",
          "score": 0,
          "city": "北京",
          "salary": "15k-30k",
          "positionAdvantage": "大公司,班车,健身房",
          "approve": 1,
          "financeStage": "上市公司",
          "industryField": "文化娱乐",
          "companySize": "2000人以上",
          "companyLabelList": [
            "免费班车",
            "岗位晋升",
            "五险一金",
            "定期体检"
          ],
          "publisherId": 8074431,
          "district": "海淀区",
          "companyLogo": "image1/M00/00/35/Cgo8PFTUXJeAJhm5AAAyDX2QCwc674.jpg",
          "positionLables": [
            "社交",
            "广告营销",
            "算法",
            "大数据",
            "用户研究"
          ],
          "industryLables": [
            "社交",
            "广告营销",
            "算法",
            "大数据",
            "用户研究"
          ],
          "businessZones": [
            "西北旺",
            "上地",
            "马连洼"
          ],
          "longitude": "116.276316",
          "latitude": "40.041543",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "16号线",
          "stationname": "马连洼",
          "linestaion": "16号线_马连洼",
          "formatCreateTime": "11:03发布"
        },
        {
          "companyId": 175557,
          "hitags": null,
          "resumeProcessRate": 26,
          "resumeProcessDay": 1,
          "companyFullName": "便利蜂商贸有限公司",
          "imState": "disabled",
          "lastLogin": 1519907912000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "3-5年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 4169884,
          "companyShortName": "便利蜂",
          "createTime": "2018-02-28 12:25:13",
          "score": 0,
          "city": "北京",
          "salary": "25k-50k",
          "positionAdvantage": "发展空间",
          "approve": 1,
          "financeStage": "不需要融资",
          "industryField": "移动互联网,生活服务",
          "companySize": "2000人以上",
          "companyLabelList": [
            "弹性工作",
            "美女多",
            "帅哥多",
            "领导好"
          ],
          "publisherId": 7131879,
          "district": "朝阳区",
          "companyLogo": "i/image2/M00/2A/4D/CgoB5looy_CACzXgAABBPuC6iGQ532.jpg",
          "positionLables": [
            "算法",
            "机器学习",
            "反作弊",
            "数据分析"
          ],
          "industryLables": [],
          "businessZones": null,
          "longitude": "116.448043",
          "latitude": "39.971134",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "10号线",
          "stationname": "太阳宫",
          "linestaion": "10号线_芍药居;10号线_太阳宫;10号线_三元桥;13号线_芍药居;13号线_光熙门;机场线_三元桥",
          "formatCreateTime": "1天前发布"
        },
        {
          "companyId": 120733,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 2,
          "companyFullName": "杭州融逸资产管理有限公司",
          "imState": "today",
          "lastLogin": 1519887872000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘",
          "workYear": "1-3年",
          "education": "大专",
          "jobNature": "全职",
          "positionId": 4002047,
          "companyShortName": "一点金库",
          "createTime": "2018-02-25 12:53:16",
          "score": 0,
          "city": "杭州",
          "salary": "12k-16k",
          "positionAdvantage": "周末双休,弹性作息,免费零食,出国旅游",
          "approve": 1,
          "financeStage": "A轮",
          "industryField": "移动互联网,金融",
          "companySize": "50-150人",
          "companyLabelList": [
            "带薪年假",
            "节日礼物",
            "五险一金",
            "周末双休"
          ],
          "publisherId": 4602257,
          "district": "西湖区",
          "companyLogo": "i/image2/M00/12/AB/CgotOVnur6uAF0F0AAAnKw6Ka6U038.png",
          "positionLables": [
            "数据分析",
            "算法",
            "大数据"
          ],
          "industryLables": [],
          "businessZones": null,
          "longitude": "120.124783",
          "latitude": "30.277036",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "2号线",
          "stationname": "古翠路",
          "linestaion": "2号线_学院路;2号线_古翠路",
          "formatCreateTime": "2018-02-25"
        },
        {
          "companyId": 82991,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 1,
          "companyFullName": "北京数美时代科技有限公司",
          "imState": "today",
          "lastLogin": 1519901156000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "1-3年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 3444397,
          "companyShortName": "数美",
          "createTime": "2018-02-28 16:09:53",
          "score": 0,
          "city": "杭州",
          "salary": "20k-40k",
          "positionAdvantage": "期权奖励,商业保险,待遇给力,大牛云集",
          "approve": 1,
          "financeStage": "B轮",
          "industryField": "企业服务,数据服务",
          "companySize": "150-500人",
          "companyLabelList": [
            "年底双薪",
            "大数据",
            "带薪年假",
            "通讯津贴"
          ],
          "publisherId": 2117266,
          "district": "余杭区",
          "companyLogo": "i/image/M00/76/C2/CgqKkVg2fVCASEreAABS01Upo_A221.jpg",
          "positionLables": [
            "金融",
            "算法",
            "NLP",
            "大数据"
          ],
          "industryLables": [
            "金融",
            "算法",
            "NLP",
            "大数据"
          ],
          "businessZones": [
            "仓前"
          ],
          "longitude": "120.002035",
          "latitude": "30.27563",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": null,
          "stationname": null,
          "linestaion": null,
          "formatCreateTime": "1天前发布"
        },
        {
          "companyId": 3786,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 1,
          "companyFullName": "普信恒业科技发展（北京）有限公司",
          "imState": "today",
          "lastLogin": 1519894239000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "3-5年",
          "education": "硕士",
          "jobNature": "全职",
          "positionId": 4043884,
          "companyShortName": "宜信",
          "createTime": "2018-03-01 14:23:18",
          "score": 0,
          "city": "北京",
          "salary": "25k-40k",
          "positionAdvantage": "金融科技",
          "approve": 1,
          "financeStage": "上市公司",
          "industryField": "金融",
          "companySize": "2000人以上",
          "companyLabelList": [
            "管理规范",
            "技能培训",
            "扁平管理",
            "弹性工作"
          ],
          "publisherId": 817467,
          "district": "朝阳区",
          "companyLogo": "i/image/M00/67/87/CgpFT1mpHKCAF5oKAABeE95QxFk132.png",
          "positionLables": [
            "资深",
            "高级",
            "机器学习"
          ],
          "industryLables": [],
          "businessZones": [
            "大望路",
            "华贸",
            "红庙"
          ],
          "longitude": "115.99339",
          "latitude": "39.99426",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": null,
          "stationname": null,
          "linestaion": null,
          "formatCreateTime": "14:23发布"
        },
        {
          "companyId": 107784,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 1,
          "companyFullName": "上海寻梦信息技术有限公司",
          "imState": "today",
          "lastLogin": 1519905634000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "3-5年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 4155959,
          "companyShortName": "拼多多",
          "createTime": "2018-03-01 14:14:33",
          "score": 0,
          "city": "广州",
          "salary": "14k-28k",
          "positionAdvantage": "待遇好,氛围好,美食多",
          "approve": 0,
          "financeStage": "C轮",
          "industryField": "电子商务,移动互联网",
          "companySize": "500-2000人",
          "companyLabelList": [
            "股票期权",
            "专项奖金",
            "弹性工作",
            "扁平管理"
          ],
          "publisherId": 3032901,
          "district": "海珠区",
          "companyLogo": "i/image/M00/B1/1A/Cgp3O1i41miAcqAtAAFIpcEdu4s331.jpg",
          "positionLables": [
            "电商",
            "社交",
            "本地生活",
            "搜索",
            "算法"
          ],
          "industryLables": [
            "电商",
            "社交",
            "本地生活",
            "搜索",
            "算法"
          ],
          "businessZones": [
            "客村",
            "新港",
            "赤岗"
          ],
          "longitude": "113.326414",
          "latitude": "23.096313",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "8号线",
          "stationname": "客村",
          "linestaion": "3号线_客村;3号线_广州塔;8号线_客村;8号线_赤岗",
          "formatCreateTime": "14:14发布"
        },
        {
          "companyId": 229678,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 1,
          "companyFullName": "杭州比智科技有限公司",
          "imState": "today",
          "lastLogin": 1519906706000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "不限",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 4179164,
          "companyShortName": "奇点云",
          "createTime": "2018-03-01 09:49:25",
          "score": 0,
          "city": "杭州",
          "salary": "20k-40k",
          "positionAdvantage": "不打卡,带薪年假,定期体检,股票期权",
          "approve": 0,
          "financeStage": "天使轮",
          "industryField": "移动互联网、O2O",
          "companySize": "50-150人",
          "companyLabelList": [
            "年底双薪",
            "股票期权",
            "专项奖金",
            "绩效奖金"
          ],
          "publisherId": 9582063,
          "district": "余杭区",
          "companyLogo": "i/image2/M00/03/E0/CgoB5lnDJZyAO5WPAAANFzD0K1Q834.png",
          "positionLables": [
            "电商",
            "广告营销",
            "大数据",
            "数据分析"
          ],
          "industryLables": [
            "电商",
            "广告营销",
            "大数据",
            "数据分析"
          ],
          "businessZones": null,
          "longitude": "120.003852",
          "latitude": "30.291585",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": null,
          "stationname": null,
          "linestaion": null,
          "formatCreateTime": "09:49发布"
        },
        {
          "companyId": 19281,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 1,
          "companyFullName": "厦门欢乐逛科技股份有限公司",
          "imState": "today",
          "lastLogin": 1519897159000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师 (MJ000069)",
          "workYear": "不限",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 4112498,
          "companyShortName": "欢乐逛",
          "createTime": "2018-02-28 11:33:27",
          "score": 0,
          "city": "厦门",
          "salary": "15k-30k",
          "positionAdvantage": "福利多多,发展空间,腾讯团队",
          "approve": 1,
          "financeStage": "上市公司",
          "industryField": "电子商务,企业服务",
          "companySize": "150-500人",
          "companyLabelList": [
            "免费班车",
            "股票期权",
            "绩效奖金",
            "岗位晋升"
          ],
          "publisherId": 308573,
          "district": "思明区",
          "companyLogo": "i/image/M00/18/25/Cgp3O1bzVnGAP1MPAAAOAsQ5cIQ069.jpg",
          "positionLables": [
            "算法"
          ],
          "industryLables": [],
          "businessZones": [
            "前埔医院"
          ],
          "longitude": "118.19703",
          "latitude": "24.48833",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": null,
          "stationname": null,
          "linestaion": null,
          "formatCreateTime": "1天前发布"
        },
        {
          "companyId": 284128,
          "hitags": null,
          "resumeProcessRate": 97,
          "resumeProcessDay": 1,
          "companyFullName": "北京智分科技有限公司",
          "imState": "today",
          "lastLogin": 1519901596000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "1-3年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 3865597,
          "companyShortName": "NewsJet",
          "createTime": "2018-03-01 12:20:44",
          "score": 0,
          "city": "北京",
          "salary": "25k-45k",
          "positionAdvantage": "Geek范,清华系,福利待遇好,股票期权",
          "approve": 0,
          "financeStage": "不需要融资",
          "industryField": "移动互联网",
          "companySize": "50-150人",
          "companyLabelList": [
            "年底双薪",
            "免费两餐",
            "Geek范",
            "免费健身"
          ],
          "publisherId": 9378160,
          "district": "海淀区",
          "companyLogo": "i/image2/M00/22/CC/CgoB5loVbmmAcZ8MAACqA3IDUUg390.png",
          "positionLables": [
            "高级",
            "中级",
            "机器学习",
            "语音处理",
            "爬虫"
          ],
          "industryLables": [],
          "businessZones": [
            "知春路"
          ],
          "longitude": "116.351631",
          "latitude": "39.977163",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": "10号线",
          "stationname": "西土城",
          "linestaion": "10号线_知春路;10号线_西土城;13号线_大钟寺;13号线_知春路",
          "formatCreateTime": "12:20发布"
        },
        {
          "companyId": 285069,
          "hitags": null,
          "resumeProcessRate": 100,
          "resumeProcessDay": 1,
          "companyFullName": "河北乐聘网络科技有限公司",
          "imState": "today",
          "lastLogin": 1519893314000,
          "explain": null,
          "adWord": 0,
          "plus": null,
          "pcShow": 0,
          "positionName": "数据挖掘工程师",
          "workYear": "3-5年",
          "education": "本科",
          "jobNature": "全职",
          "positionId": 4142085,
          "companyShortName": "乐聘网络科技",
          "createTime": "2018-03-01 15:14:54",
          "score": 0,
          "city": "北京",
          "salary": "15k-25k",
          "positionAdvantage": "扁平管理,福利多多,六险一金,氛围活跃",
          "approve": 1,
          "financeStage": "不需要融资",
          "industryField": "移动互联网,广告营销",
          "companySize": "150-500人",
          "companyLabelList": [
            "年底双薪",
            "股票期权",
            "年终分红",
            "绩效奖金"
          ],
          "publisherId": 9328501,
          "district": "朝阳区",
          "companyLogo": "i/image2/M00/1D/99/CgotOVoJVfKAbi3UAADdQsfAW-k841.png",
          "positionLables": [
            "高级",
            "数据分析",
            "大数据",
            "算法"
          ],
          "industryLables": [],
          "businessZones": null,
          "longitude": "0.0",
          "latitude": "0.0",
          "appShow": 0,
          "deliver": 0,
          "gradeDescription": null,
          "promotionScoreExplain": null,
          "firstType": "开发/测试/运维类",
          "secondType": "数据开发",
          "isSchoolJob": 0,
          "subwayline": null,
          "stationname": null,
          "linestaion": null,
          "formatCreateTime": "15:14发布"
        }
      ]
    }
  },
  "code": 0
}
'''

# %%
import json

# %%
jr = json.loads(Rj)

# %%
Rj.count('')
# Out:
# 0

# %%
jr
# Out:
# {'hrInfoMap': {'1302830': {'canTalk': True,
#    'phone': None,
#    'portrait': None,
#    'positionName': 'HR',
#    'realName': '辛琳',
#    'receiveEmail': None,
#    'userId': 674265,
#    'userLevel': 'G1'},
#   '2603441': {'canTalk': True,
#    'phone': None,
#    'portrait': None,
#    'positionName': '招聘',
#    'realName': '李女士',
#    'receiveEmail': None,
#    'userId': 1314138,
#    'userLevel': 'G1'},
#   '3284227': {'canTalk': True,
#    'phone': None,
#    'portrait': None,
#    'positionName': '',
#    'realName': 'vicky',
#    'receiveEmail': None,
#    'userId': 8074431,
#    'userLevel': 'G1'},
#   '3440369': {'canTalk': True,
#    'phone': None,
#    'portrait': None,
#    'positionName': 'HR',
#    'realName': '京东HR',
#    'receiveEmail': None,
#    'userId': 5314132,
#    'userLevel': 'G1'},
#   '3444397': {'canTalk': True,
#    'phone': None,
#    'portrait': 'i/image/M00/4B/CC/CgpEMllnaAuARvblAAAgJXYyQFE826.jpg',
#    'positionName': 'HR',
# ...
